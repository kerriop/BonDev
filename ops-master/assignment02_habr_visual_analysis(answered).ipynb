# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению
# <center>
# Автор материала: Екатерина Демидова, Data Scientist @ Segmento <br>
#
#
# Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.
# Автор материала:

# %% [markdown]
# # <center>Домашнее задание № 2 (демо). <br> Визуальный анализ данных о публикациях на Хабрахабре</center>
#
# **Заполните код в клетках и ответьте на вопросы в [веб-форме](https://docs.google.com/forms/d/1y8qj5iYpaVhczjWnZuHd5NRR_sdCGy3eTF5n-qPKknQ).**

# %%
import pandas as pd
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10, 8)

# %% [markdown]
# ## Загрузка и знакомство с данными
#
# Для работы вам понадобятся предобработанные данные нашего учебного конкурса на kaggle [«Прогноз популярности статьи на Хабре»](https://www.kaggle.com/c/howpop-habrahabr-favs).

# %%
df = pd.read_csv('../../data/howpop_train.csv')

# %%
df.shape
# Out:
# (134137, 17)

# %%
df.head(3).T
# Out:
#                                                                0  \
# url                             https://habrahabr.ru/post/18284/
# domain                                              habrahabr.ru
# post_id                                                    18284
# published                                    2008-01-01 18:19:00
# author                                                    @Tapac
# flow                                                     develop
# polling                                                    False
# content_len                                                 4305
# title             Новогодний подарок блоггерам — WordPress 2.3.2
# comments                                                       0
# favs                                                           0
# views                                                        236
# votes_plus                                                     0
# votes_minus                                                    0
# views_lognorm                                          -0.792687
# favs_lognorm                                            -1.34407
# comments_lognorm                                        -2.43687
#
#                                                                   1  \
# url                                https://habrahabr.ru/post/18285/
# domain                                                 habrahabr.ru
# post_id                                                       18285
# published                                       2008-01-01 18:30:00
# author                                                   @DezmASter
# flow                                                         design
# polling                                                       False
# content_len                                                    7344
# title             Сумасшедшие яйца, или сервис для отслеживания ...
# comments                                                          1
# favs                                                              1
# views                                                           353
# votes_plus                                                        1
# votes_minus                                                       0
# views_lognorm                                             -0.485214
# favs_lognorm                                              -0.831946
# comments_lognorm                                           -1.87319
#
#                                                                   2
# url                                https://habrahabr.ru/post/18286/
# domain                                                 habrahabr.ru
# post_id                                                       18286
# published                                       2008-01-01 18:34:00
# author                                                   @DezmASter
# flow                                                         design
# polling                                                       False
# content_len                                                    8431
# title             Сумасшедшие яйца, или сервис для отслеживания ...
# comments                                                         47
# favs                                                             72
# views                                                          1200
# votes_plus                                                       45
# votes_minus                                                       5
# views_lognorm                                               0.44609
# favs_lognorm                                                1.79402
# comments_lognorm                                           0.574656

# %% [markdown]
# Избавимся сразу от переменных, названия которых заканчиваются на `_lognorm` (нужны для соревнования на Kaggle). Выберем их с помощью `filter()` и удалим `drop`-ом:

# %%
df.drop(filter(lambda c: c.endswith('_lognorm'), df.columns), 
        axis = 1,       # axis = 1: столбцы 
        inplace = True) # избавляет от необходимости сохранять датасет

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# post_id      134137.0  181307.054265  81766.350702  18284.0  115565.0
# content_len  134137.0    7516.929699   8724.771640      1.0    2179.0
# comments     134137.0      39.625994     62.398958      0.0       7.0
# favs         134137.0      71.999866    145.854135      0.0       8.0
# views        134137.0   16631.013084  31479.819691      3.0    2100.0
# votes_plus   133566.0      35.536888     42.461073      0.0      11.0
# votes_minus  133566.0       8.050035     11.398282      0.0       2.0
#
#                   50%       75%        max
# post_id      182666.0  257401.0   314088.0
# content_len    4949.0    9858.0   352471.0
# comments         19.0      48.0     2266.0
# favs             27.0      78.0     8718.0
# views          7600.0   18700.0  1730000.0
# votes_plus       22.0      45.0     1466.0
# votes_minus       5.0      10.0      445.0

# %%
df.describe(include = ['object', 'bool'] # бинарные и категориальные переменные
           ).T
# Out:
#             count  unique                                             top  \
# url        134137  134137  https://habrahabr.ru/company/tceh/blog/250333/
# domain     134137       2                                    habrahabr.ru
# published  134137  130291                             2011-06-14 15:52:00
# author      97657   22077                                         @alizar
# flow        97048       6                                         develop
# polling    134137       2                                           False
# title      134137  133628     Интересные события, произошедшие в выходные
#
#              freq
# url             1
# domain      97048
# published      39
# author       5292
# flow        53318
# polling    129412
# title          56

# %%
# настройка внешнего вида графиков в seaborn
sns.set_style("dark")
sns.set_palette("RdBu")
#sns.set_context("notebook", font_scale = 1.5, 
               # rc = { "figure.figsize" : (200, 100), "axes.titlesize" : 40 })

# %% [markdown]
# Столбец **`published`** (время публикации) содержит строки. Чтобы мы могли работать с этими данными как с датой/временем публикации, приведём их к типу `datetime`:

# %%
print(df.published.dtype)
df['published'] = pd.to_datetime(df.published, yearfirst = True)
print(df.published.dtype)
# Out:
# object
# datetime64[ns]

# %% [markdown]
# Создадим несколько столбцов на основе данных о времени публикации:

# %%
df['year'] = [d.year for d in df.published]
df['month'] = [d.month for d in df.published]

df['dayofweek'] = [d.isoweekday() for d in df.published]
df['hour'] = [d.hour for d in df.published]

# %%
df
# Out:
#                                                       url        domain  \
# 0                        https://habrahabr.ru/post/18284/  habrahabr.ru
# 1                        https://habrahabr.ru/post/18285/  habrahabr.ru
# 2                        https://habrahabr.ru/post/18286/  habrahabr.ru
# 3                        https://habrahabr.ru/post/18291/  habrahabr.ru
# 4                        https://geektimes.ru/post/18294/  geektimes.ru
# 5                        https://habrahabr.ru/post/18295/  habrahabr.ru
# 6                        https://geektimes.ru/post/18306/  geektimes.ru
# 7                        https://habrahabr.ru/post/18311/  habrahabr.ru
# 8                        https://habrahabr.ru/post/31352/  habrahabr.ru
# 9                        https://habrahabr.ru/post/18314/  habrahabr.ru
# 10                       https://geektimes.ru/post/18316/  geektimes.ru
# 11                       https://habrahabr.ru/post/18318/  habrahabr.ru
# 12                       https://habrahabr.ru/post/18323/  habrahabr.ru
# 13                       https://geektimes.ru/post/18328/  geektimes.ru
# 14                       https://habrahabr.ru/post/18329/  habrahabr.ru
# 15                       https://habrahabr.ru/post/35218/  habrahabr.ru
# 16                       https://habrahabr.ru/post/18332/  habrahabr.ru
# 17                       https://geektimes.ru/post/18333/  geektimes.ru
# 18                       https://habrahabr.ru/post/18334/  habrahabr.ru
# 19                       https://habrahabr.ru/post/18335/  habrahabr.ru
# 20                       https://habrahabr.ru/post/18336/  habrahabr.ru
# 21                       https://habrahabr.ru/post/18337/  habrahabr.ru
# 22                       https://habrahabr.ru/post/18339/  habrahabr.ru
# 23                       https://habrahabr.ru/post/18341/  habrahabr.ru
# 24                       https://habrahabr.ru/post/18349/  habrahabr.ru
# 25                       https://habrahabr.ru/post/18356/  habrahabr.ru
# 26                       https://habrahabr.ru/post/18362/  habrahabr.ru
# 27                       https://habrahabr.ru/post/18363/  habrahabr.ru
# 28                       https://geektimes.ru/post/18367/  geektimes.ru
# 29                       https://habrahabr.ru/post/31353/  habrahabr.ru
# ...                                                   ...           ...
# 134107  https://geektimes.ru/company/gearbest/blog/282...  geektimes.ru
# 134108                  https://habrahabr.ru/post/314020/  habrahabr.ru
# 134109                  https://habrahabr.ru/post/314048/  habrahabr.ru
# 134110   https://geektimes.ru/company/mailru/blog/282070/  geektimes.ru
# 134111    https://habrahabr.ru/company/jugru/blog/313846/  habrahabr.ru
# 134112                  https://habrahabr.ru/post/314054/  habrahabr.ru
# 134113                  https://geektimes.ru/post/282076/  geektimes.ru
# 134114    https://habrahabr.ru/company/badoo/blog/314046/  habrahabr.ru
# 134115                  https://habrahabr.ru/post/314038/  habrahabr.ru
# 134116                  https://habrahabr.ru/post/314056/  habrahabr.ru
# 134117  https://geektimes.ru/company/hashflare/blog/28...  geektimes.ru
# 134118                  https://habrahabr.ru/post/313948/  habrahabr.ru
# 134119                  https://habrahabr.ru/post/314060/  habrahabr.ru
# 134120                  https://geektimes.ru/post/282080/  geektimes.ru
# 134121                  https://geektimes.ru/post/282084/  geektimes.ru
# 134122                  https://geektimes.ru/post/282078/  geektimes.ru
# 134123     https://habrahabr.ru/company/miip/blog/313322/  habrahabr.ru
# 134124                  https://habrahabr.ru/post/314072/  habrahabr.ru
# 134125      https://habrahabr.ru/company/3cx/blog/314074/  habrahabr.ru
# 134126                  https://habrahabr.ru/post/314076/  habrahabr.ru
# 134127                  https://habrahabr.ru/post/314068/  habrahabr.ru
# 134128                  https://habrahabr.ru/post/314078/  habrahabr.ru
# 134129                  https://habrahabr.ru/post/314040/  habrahabr.ru
# 134130                  https://habrahabr.ru/post/314082/  habrahabr.ru
# 134131                  https://habrahabr.ru/post/313960/  habrahabr.ru
# 134132   https://habrahabr.ru/company/mailru/blog/314014/  habrahabr.ru
# 134133                  https://geektimes.ru/post/282086/  geektimes.ru
# 134134                  https://geektimes.ru/post/282090/  geektimes.ru
# 134135                  https://geektimes.ru/post/282092/  geektimes.ru
# 134136                  https://habrahabr.ru/post/314088/  habrahabr.ru
#
#         post_id           published             author        flow  polling  \
# 0         18284 2008-01-01 18:19:00             @Tapac     develop    False
# 1         18285 2008-01-01 18:30:00         @DezmASter      design    False
# 2         18286 2008-01-01 18:34:00         @DezmASter      design    False
# 3         18291 2008-01-02 01:32:00           @Taoorus      design    False
# 4         18294 2008-01-02 14:34:00           @dennydo         NaN    False
# 5         18295 2008-01-02 16:14:00              @lvea     develop    False
# 6         18306 2008-01-03 12:55:00           @abbasov         NaN    False
# 7         18311 2008-01-03 17:20:00            @Andrey        misc    False
# 8         31352 2008-01-03 22:54:00         @kvladimir     develop    False
# 9         18314 2008-01-03 23:56:00              @lvea     develop    False
# 10        18316 2008-01-04 00:48:00             @caxep         NaN    False
# 11        18318 2008-01-04 01:23:00             @clops     develop    False
# 12        18323 2008-01-04 13:39:00   @vasilyyaremchuk  management    False
# 13        18328 2008-01-04 18:44:00      @suckdontbite         NaN    False
# 14        18329 2008-01-04 18:48:00               @blv       admin    False
# 15        35218 2008-01-04 19:04:00           @napster     develop     True
# 16        18332 2008-01-04 20:41:00         @hightower        misc    False
# 17        18333 2008-01-04 23:07:00            @agl666         NaN    False
# 18        18334 2008-01-04 23:18:00          @Shpankov     develop    False
# 19        18335 2008-01-04 23:22:00          @Shpankov     develop    False
# 20        18336 2008-01-04 23:28:00          @Shpankov     develop    False
# 21        18337 2008-01-04 23:30:00          @Shpankov     develop    False
# 22        18339 2008-01-04 23:33:00          @Shpankov     develop    False
# 23        18341 2008-01-04 23:37:00          @Shpankov     develop    False
# 24        18349 2008-01-05 13:10:00            @calg0n       admin    False
# 25        18356 2008-01-05 17:26:00            @agl666        misc    False
# 26        18362 2008-01-05 20:33:00             @kudzu     develop    False
# 27        18363 2008-01-05 21:43:00           @Langraf     develop    False
# 28        18367 2008-01-06 02:48:00        @CurlyBrace         NaN    False
# 29        31353 2008-01-06 11:29:00           @vladbuk     develop    False
# ...         ...                 ...                ...         ...      ...
# 134107   282074 2016-10-31 16:32:00                NaN         NaN    False
# 134108   314020 2016-10-31 16:38:00            @corlin  management    False
# 134109   314048 2016-10-31 16:41:00         @darthunix     develop    False
# 134110   282070 2016-10-31 16:52:00                NaN         NaN    False
# 134111   313846 2016-10-31 17:14:00                NaN     develop    False
# 134112   314054 2016-10-31 17:23:00       @Rainvention  management    False
# 134113   282076 2016-10-31 17:24:00          @ragequit         NaN    False
# 134114   314046 2016-10-31 17:28:00                NaN     develop    False
# 134115   314038 2016-10-31 17:44:00         @LinuxComp     develop     True
# 134116   314056 2016-10-31 17:49:00         @Grossmend     develop    False
# 134117   282082 2016-10-31 17:51:00                NaN         NaN    False
# 134118   313948 2016-10-31 18:04:00       @PatientZero      design    False
# 134119   314060 2016-10-31 18:05:00        @MoreBeauty     develop    False
# 134120   282080 2016-10-31 18:46:00          @krasandm         NaN    False
# 134121   282084 2016-10-31 18:58:00            @alizar         NaN    False
# 134122   282078 2016-10-31 19:05:00             @marks         NaN    False
# 134123   313322 2016-10-31 19:18:00                NaN     develop    False
# 134124   314072 2016-10-31 19:29:00            @All4DK     develop    False
# 134125   314074 2016-10-31 19:36:00                NaN       admin    False
# 134126   314076 2016-10-31 19:40:00  @Roman_Yankovskiy  management    False
# 134127   314068 2016-10-31 19:53:00            @plan_A     develop    False
# 134128   314078 2016-10-31 19:54:00  @semen_grinshtein  management    False
# 134129   314040 2016-10-31 20:01:00         @MACROSCOP     develop    False
# 134130   314082 2016-10-31 20:29:00         @alexeev_n  management    False
# 134131   313960 2016-10-31 21:08:00         @Nuteralie  management    False
# 134132   314014 2016-10-31 21:45:00                NaN     develop    False
# 134133   282086 2016-10-31 22:44:00             @marks         NaN    False
# 134134   282090 2016-10-31 23:26:00          @Shapelez         NaN    False
# 134135   282092 2016-10-31 23:52:00          @ragequit         NaN    False
# 134136   314088 2016-10-31 23:56:00             @Mgrin     develop    False
#
#         content_len                                              title  \
# 0              4305     Новогодний подарок блоггерам — WordPress 2.3.2
# 1              7344  Сумасшедшие яйца, или сервис для отслеживания ...
# 2              8431  Сумасшедшие яйца, или сервис для отслеживания ...
# 3              5662     Сглаживание шрифтов, и субпиксельная отрисовка
# 4              3706                      Почему мне не нравится iPhone
# 5              3171                     Mobile2.0 Всеобщая доступность
# 6               435                                 Modbook в действии
# 7              3291                     В чем суть проекта Vladelia.ru
# 8              1953  Подтверждено: Wikia Search запускается в понед...
# 9              3712   Mobile 2.0 Выбор предпочтительного способа связи
# 10             6553                      Обзор «лаунчеров» под Windows
# 11             7099                                     Онлайн Банкинг
# 12             1332                         Оформление рабочего места.
# 13             1698                        Новые скриншоты Cairo Shell
# 14             9033                         Шанс для альтернативных ОС
# 15                1  Кто должен писать JS код в процессе работы над...
# 16            11781  TOP-10 западных стартапов, на которые стоит об...
# 17             1215                           Чтение Википедии оффлайн
# 18              979                                  Исторический кадр
# 19             1205                                       Оперный боец
# 20              859                         Оперное мини-расследование
# 21              654                                  Хочу телебраузер!
# 22              863                        Opera 9.5 SDK для устройств
# 23             1248                             И снова о популярности
# 24             1301  Установка драйвера для видяхи NVIDIA в Ubuntu ...
# 25             1037  Скрытие всей ветки комментариев если родительс...
# 26              202                          М.Грубер — Понимание SQL.
# 27             1175                                            9 монет
# 28             2240    Перепрошить мобилу или Всегда бывает первый раз
# 29              591                    Краткий справочник по Вордпресс
# ...             ...                                                ...
# 134107        16712  Осенний смартфонопад: китайский «Galaxy Note 7...
# 134108        22013          Работаем с бюджетным учреждением. Часть 4
# 134109        13294       Техника безопасности при работе с PostgreSQL
# 134110        13714  Geek Halloween: необычные DIY-костюмы на Хеллоуин
# 134111         9100  «Требования к надёжности у нас выше, чем в сре...
# 134112         5733    Редактируем безнадежное письмо службы поддержки
# 134113         3557  Рекламная система Facebook позволяет фильтрова...
# 134114        11687  Как я сходил на первый в России «Testathon», х...
# 134115         8629  Как превратить смартфон в микрофон (идеи и воп...
# 134116        26872  Оптимизация на примере. Муравьиный алгоритм (A...
# 134117        11453  Криптовалюты на выручку е-коммерсу: когда плат...
# 134118         9960            Советы по пропорциям и масштабу в играх
# 134119        31088                TextBlock с подсветкой текста (WPF)
# 134120         8595  Стволовые клетки могут успешно заменить умерши...
# 134121        13083                             Цифровой Хэллоуин 2016
# 134122         5841  Люминесценция помогает ученым изучать работу о...
# 134123         8618  Реалии работы геймдизайнером в большой студии ...
# 134124         2559                      Простые и удобные уведомления
# 134125         4052  Выпущена 3CX Phone System V15 SP3 и интеграция...
# 134126         6462          Проверяем партнера по открытым источникам
# 134127        13905  ASO оптимизация. Составление семантического яд...
# 134128        13832   Как Windows NT стала «убийцей» Novell NetWare OS
# 134129         8493  Как найти вектор развития программного продукт...
# 134130         4529  Почему в очередной раз проваливается внедрение...
# 134131         7104  Большое количество людей в опенспейсе мешает с...
# 134132        56033                     Парсинг JSON — это минное поле
# 134133         5504  Заработала система раннего предупреждения НАСА...
# 134134         2883  Арзамасский городской суд постановил заблокиро...
# 134135         5735  Медиа-коммуникационный союз планирует внести в...
# 134136         9359  mgr-forms-react: Простой компонент для простей...
#
#         comments  favs  views  votes_plus  votes_minus  year  month  \
# 0              0     0    236         0.0          0.0  2008      1
# 1              1     1    353         1.0          0.0  2008      1
# 2             47    72   1200        45.0          5.0  2008      1
# 3            102    36   5700        72.0          3.0  2008      1
# 4            230     6   1400        73.0         15.0  2008      1
# 5             22     1    192         9.0          2.0  2008      1
# 6             10     0    301         5.0          1.0  2008      1
# 7             64     1    141        17.0         20.0  2008      1
# 8             23     2    208        21.0          3.0  2008      1
# 9              6     1    401         2.0          0.0  2008      1
# 10            50    10   6300        19.0          3.0  2008      1
# 11           154    21   3400        29.0          7.0  2008      1
# 12           406     7   3900        27.0         14.0  2008      1
# 13            22     7    653        19.0          3.0  2008      1
# 14           177     3    668        33.0          5.0  2008      1
# 15           105     1   1200        25.0         14.0  2008      1
# 16            19    31    769        24.0          2.0  2008      1
# 17            30     4  11100        11.0          1.0  2008      1
# 18             2     1    202        15.0         10.0  2008      1
# 19            19     0    309        29.0         12.0  2008      1
# 20            83     0    127        15.0         11.0  2008      1
# 21            10     0    187         6.0         11.0  2008      1
# 22             2     0    181        10.0          8.0  2008      1
# 23            37     0    175        12.0         13.0  2008      1
# 24            18     2    656         8.0          5.0  2008      1
# 25             6     0    158         6.0          3.0  2008      1
# 26            36    26  17000        45.0          9.0  2008      1
# 27            44     1    397         7.0          7.0  2008      1
# 28             0     0    217         0.0          0.0  2008      1
# 29            19    39   1900        32.0          3.0  2008      1
# ...          ...   ...    ...         ...          ...   ...    ...
# 134107        91    21  28000        16.0          4.0  2016     10
# 134108         3    39   2700        11.0          1.0  2016     10
# 134109        43   310  17000        71.0          4.0  2016     10
# 134110        11    24  12500        26.0          7.0  2016     10
# 134111         6    44   7800        28.0          0.0  2016     10
# 134112        75    37  10300        55.0          4.0  2016     10
# 134113        59    12  13600        21.0          6.0  2016     10
# 134114        13    21   6200        29.0          2.0  2016     10
# 134115        39    45   4000        12.0          7.0  2016     10
# 134116         7    83   5700        22.0          1.0  2016     10
# 134117        22    19   6300        18.0          5.0  2016     10
# 134118         1   111   8800        37.0          1.0  2016     10
# 134119        14    45   3700         7.0          2.0  2016     10
# 134120        34    28   7800        16.0          0.0  2016     10
# 134121        16     9  10100        24.0          4.0  2016     10
# 134122         3    12   3200        13.0          0.0  2016     10
# 134123         7    61  11700        15.0          4.0  2016     10
# 134124        12    69   6000        16.0          3.0  2016     10
# 134125         2     6    865         7.0          1.0  2016     10
# 134126        19   303  19400        34.0          1.0  2016     10
# 134127        16    53   5900        13.0          0.0  2016     10
# 134128        31    32  16700        40.0          0.0  2016     10
# 134129        12    38   2900         6.0          0.0  2016     10
# 134130        30    36   4500        10.0         14.0  2016     10
# 134131        82    44  18500        36.0          4.0  2016     10
# 134132        58   347  35500       164.0          6.0  2016     10
# 134133        52    16  12900        22.0          0.0  2016     10
# 134134        16    14  15800        28.0          4.0  2016     10
# 134135        47    14  15000        20.0          0.0  2016     10
# 134136         4    35   3100        12.0          1.0  2016     10
#
#         dayofweek  hour
# 0               2    18
# 1               2    18
# 2               2    18
# 3               3     1
# 4               3    14
# 5               3    16
# 6               4    12
# 7               4    17
# 8               4    22
# 9               4    23
# 10              5     0
# 11              5     1
# 12              5    13
# 13              5    18
# 14              5    18
# 15              5    19
# 16              5    20
# 17              5    23
# 18              5    23
# 19              5    23
# 20              5    23
# 21              5    23
# 22              5    23
# 23              5    23
# 24              6    13
# 25              6    17
# 26              6    20
# 27              6    21
# 28              7     2
# 29              7    11
# ...           ...   ...
# 134107          1    16
# 134108          1    16
# 134109          1    16
# 134110          1    16
# 134111          1    17
# 134112          1    17
# 134113          1    17
# 134114          1    17
# 134115          1    17
# 134116          1    17
# 134117          1    17
# 134118          1    18
# 134119          1    18
# 134120          1    18
# 134121          1    18
# 134122          1    19
# 134123          1    19
# 134124          1    19
# 134125          1    19
# 134126          1    19
# 134127          1    19
# 134128          1    19
# 134129          1    20
# 134130          1    20
# 134131          1    21
# 134132          1    21
# 134133          1    22
# 134134          1    23
# 134135          1    23
# 134136          1    23
#
# [134137 rows x 18 columns]

# %% [markdown]
# -----
# Теперь Ваша очередь. В каждом пункте предлагается построить картинку и с ее помощью ответить на вопрос в [форме](https://docs.google.com/forms/d/e/1FAIpQLSf3b5OG8zX_nLQBQ-t20c6M5Auz-VUL-yxj8Fm9_o_XWDBTrg/viewform?c=0&w=1). Конечно, можно попытаться ответить на все вопросы только с Pandas, без картинок, но мы советуем Вам потренироваться строить (красивые) визуализации.

# %% [markdown]
# ## 1\. В каком месяце (и какого года) было больше всего публикаций?
#
# * март 2016
# * март 2015
# * апрель 2015
# * апрель 2016

# %%
sns.countplot(x='year', hue='month', data=df);

# %% [markdown]
# ## 2\. Проанализируйте публикации в месяце из предыдущего вопроса
#
# Выберите один или несколько вариантов:
#
# * Один или несколько дней сильно выделяются из общей картины
# * На хабре _всегда_ больше статей, чем на гиктаймсе
# * По субботам на гиктаймс и на хабрахабр публикуют примерно одинаковое число статей
#
# Подсказки: постройте график зависимости числа публикаций от дня; используйте параметр `hue`; не заморачивайтесь сильно с ответами и не ищите скрытого смысла :)

# %%
sns.countplot(x='dayofweek', hue='domain', data=df[(df['year'] == 2015) & (df['month'] == 3)]);

# %% [markdown]
# ## 3\. Когда лучше всего публиковать статью?
#
# * Больше всего просмотров набирают статьи, опубликованные в 12 часов дня
# * У опубликованных в 10 утра постов больше всего комментариев
# * Больше всего просмотров набирают статьи, опубликованные в 6 часов утра
# * Максимальное число комментариев на гиктаймсе набрала статья, опубликованная в 9 часов вечера
# * На хабре дневные статьи комментируют чаще, чем вечерние

# %%
df.groupby('hour')['views'].mean().plot(kind='bar')

# %%
df[df['domain'] == 'geektimes.ru'].groupby('hour')['comments'].max().plot(kind='bar')

# %%
df.groupby('hour')['comments'].mean().plot(kind='bar')

# %%
df[df['domain'] == 'habrahabr.ru'].groupby('hour')['comments'].mean().plot(kind='bar')

# %% [markdown]
# ## 4\. Кого из топ-20 авторов чаще всего минусуют?
#
# * @Mordatyj
# * @Mithgol
# * @alizar
# * @ilya42

# %%
top_authors = df['author'].value_counts().sort_values(ascending = False).head(20).index.values
sns.boxplot(y="author", x="votes_minus", 
            data=df[df['author'].isin(top_authors)], orient="h");

# %% [markdown]
# ## 5\. Сравните субботы и понедельники
#
# Правда ли, что по субботам авторы пишут в основном днём, а по понедельникам — в основном вечером?

# %%
sns.countplot(x='hour', hue='dayofweek', data=df[(df['dayofweek'] == 1) | (df['dayofweek'] == 6)]);
